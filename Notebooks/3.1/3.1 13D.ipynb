# %%
fx = sy.cos(x) + sy.sin(x)
f = sy.lambdify(x, fx)
y = sy.symbols('y')

# %%
def lagrange(nodes, fx, sym_x):
    nodes.sort()
    eq = sy.sympify(0.0)
    for i, k in enumerate(nodes):
        a = fx(k)
        L_denom, L_num = 1, 1
        print(nodes[0:i], nodes[i+1:])
        for j in nodes[0:i] + nodes[i+1:]:
            L_denom *= (x - j)
            L_num *= (k - j)
        eq += a * (L_denom / L_num)
    return eq

# %%
xn = [0, 0.25, 0.5, 1]

# %%
tex(lagrange(xn, f, x))
# Out:
# [] [0.25, 0.5, 1]
# [0] [0.5, 1]
# [0, 0.25] [1]
# [0, 0.25, 0.5] []

# %%
tex(get_diffs(fx, 4)[4])
